# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model1_pred = pd.read_csv('data/rnn_predictions_1.csv', index_col = 0)
model1_res = pd.read_csv('data/rnn_results_1.csv', index_col = 0)

model2_pred = pd.read_csv('data/rnn_predictions_2.csv', index_col = 0)
model2_res = pd.read_csv('data/rnn_results_2.csv', index_col = 0)

model3_pred = pd.read_csv('data/rnn_predictions_3.csv', index_col = 0)
model3_res = pd.read_csv('data/rnn_results_3.csv', index_col = 0)

model4_pred = pd.read_csv('data/rnn_predictions_4.csv', index_col = 0)
model4_res = pd.read_csv('data/rnn_results_4.csv', index_col = 0)

model5_pred = pd.read_csv('data/rnn_predictions_5.csv', index_col = 0)
model5_res = pd.read_csv('data/rnn_results_5.csv', index_col = 0)

model6_pred = pd.read_csv('data/rnn_predictions_6.csv', index_col = 0)
model6_res = pd.read_csv('data/rnn_results_6.csv', index_col = 0)

model7_pred = pd.read_csv('data/rnn_predictions_7.csv', index_col = 0)
model7_res = pd.read_csv('data/rnn_results_7.csv', index_col = 0)

model8_pred = pd.read_csv('data/rnn_predictions_8.csv', index_col = 0)
model8_res = pd.read_csv('data/rnn_results_8.csv', index_col = 0)

model9_pred = pd.read_csv('data/rnn_predictions_9.csv', index_col = 0)
model9_res = pd.read_csv('data/rnn_results_9.csv', index_col = 0)

model10_pred = pd.read_csv('data/rnn_predictions_10.csv', index_col = 0)
model10_res = pd.read_csv('data/rnn_results_10.csv', index_col = 0)

model11_pred = pd.read_csv('data/rnn_predictions_11.csv', index_col = 0)
model11_res = pd.read_csv('data/rnn_results_11.csv', index_col = 0)

model12_pred = pd.read_csv('data/rnn_predictions_12.csv', index_col = 0)
model12_res = pd.read_csv('data/rnn_results_12.csv', index_col = 0)

model_mega_res = pd.read_csv('data/rnn_results_1to12.csv', index_col = 0)

# %%
model_mega_res = pd.read_csv('data/rnn_results_1to12.csv', index_col = 0)

# %%
model_mega_res['time_delta'] = pd.to_timedelta(model_mega_res['time'])

# %%
model_mega_res.describe()
# Out:
#          model_num       epochs           r2          mae          mse  \
# count  5500.000000  6000.000000  6000.000000  6000.000000  6000.000000
# mean    148.227273    46.973000     0.191076     0.229555     0.216217
# std     101.859834    18.687254     0.003268     0.001580     0.000874
# min       1.000000    26.000000     0.136683     0.226045     0.215202
# 25%      69.000000    33.000000     0.190335     0.228568     0.215723
# 50%     138.000000    43.000000     0.191920     0.229233     0.215991
# 75%     207.000000    56.000000     0.192923     0.230116     0.216414
# max     500.000000   250.000000     0.194872     0.245408     0.230755
#
#               rmse    max_error       layers      density  \
# count  6000.000000  6000.000000  6000.000000  6000.000000
# mean      0.464990     5.236998     4.000000    96.000000
# std       0.000935     0.013830     1.633129    32.002667
# min       0.463898     5.162637     2.000000    64.000000
# ...

# %%
model_mega_res.epochs.sum()
# Out:
# 281838

# %%
model_mega_res.time_delta.sum()
# Out:
# Timedelta('14 days 00:23:29.732280')

# %%
model3_res.describe()
# Out:
#         model_num     epochs          r2         mae         mse        rmse  \
# count  500.000000  500.00000  500.000000  500.000000  500.000000  500.000000
# mean   250.500000   45.17600    0.190653    0.229727    0.216329    0.465111
# std    144.481833   15.84864    0.002967    0.001365    0.000793    0.000850
# min      1.000000   26.00000    0.163453    0.227598    0.215510    0.464231
# 25%    125.750000   33.00000    0.189713    0.228854    0.215847    0.464594
# 50%    250.500000   42.00000    0.191550    0.229463    0.216090    0.464854
# 75%    375.250000   54.00000    0.192457    0.230240    0.216581    0.465382
# max    500.000000  177.00000    0.193719    0.239505    0.223600    0.472863
#
#         max_error  layers  density
# count  500.000000   500.0    500.0
# mean     5.245355     4.0     64.0
# std      0.009758     0.0      0.0
# min      5.213970     4.0     64.0
# 25%      5.239168     4.0     64.0
# 50%      5.244975     4.0     64.0
# ...

# %%
model4_res.describe()
# Out:
#         model_num      epochs          r2         mae         mse        rmse  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   250.500000   46.928000    0.190487    0.229717    0.216374    0.465159
# std    144.481833   17.753117    0.004165    0.001805    0.001113    0.001189
# min      1.000000   26.000000    0.151939    0.227490    0.215546    0.464270
# 25%    125.750000   33.000000    0.189875    0.228748    0.215822    0.464566
# 50%    250.500000   43.000000    0.191581    0.229247    0.216081    0.464846
# 75%    375.250000   56.000000    0.192554    0.230097    0.216538    0.465336
# max    500.000000  124.000000    0.193583    0.245402    0.226677    0.476107
#
#         max_error
# count  500.000000
# mean     5.242361
# std      0.014088
# min      5.196588
# 25%      5.233221
# 50%      5.241555
# 75%      5.251916
# max      5.290030

# %%
fig, ax = plt.subplots(2,4, figsize = (10,7.5))

plt.subplots_adjust(hspace = 0.1, wspace = 0.6)

ax1 = sns.boxplot(y = model3_res['epochs'], ax = ax[0,0])
#ax = sns.swarmplot(y = model4_res['epochs'], color = '.25', ax = axes[0,0])

ax2 = sns.boxplot(y = model4_res['epochs'], ax = ax[0,1])
#ax = sns.swarmplot(y = model3_res['epochs'], color = '.25', ax = axes[0,1])

ax3 = sns.boxplot(y = model3_res['r2'], ax = ax[0,2])
#ax = sns.swarmplot(y = model4_res['mae'], color = '.25', ax = axes[1,0])

ax4 = sns.boxplot(y = model4_res['r2'], ax = ax[0,3])
#ax = sns.swarmplot(y = model4_res['mae'], color = '.25', ax = axes[1,0])

ax5 = sns.boxplot(y = model3_res['mae'], ax = ax[1,0])
#ax = sns.swarmplot(y = model4_res['mae'], color = '.25', ax = axes[1,0])

ax6 = sns.boxplot(y = model4_res['mae'], ax = ax[1,1])
#ax = sns.swarmplot(y = model3_res['mae'], color = '.25', ax = axes[1,1])

ax7 = sns.boxplot(y = model3_res['mse'], ax = ax[1,2])
#ax = sns.swarmplot(y = model4_res['mae'], color = '.25', ax = axes[1,0])

ax8 = sns.boxplot(y = model4_res['mse'], ax = ax[1,3])
#ax = sns.swarmplot(y = model3_res['mae'], color = '.25', ax = axes[1,1])

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots(1, 12, figsize  = (12,8), sharey = True)

plt.subplots_adjust(hspace = 0.5, wspace = 0.1)

ax0 = sns.boxplot(y = model1_res['epochs'], ax = ax[0], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax1 = sns.boxplot(y = model2_res['epochs'], ax = ax[1], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax2 = sns.boxplot(y = model3_res['epochs'], ax = ax[2], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax3 = sns.boxplot(y = model4_res['epochs'], ax = ax[3], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax4 = sns.boxplot(y = model5_res['epochs'], ax = ax[4], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax5 = sns.boxplot(y = model6_res['epochs'], ax = ax[5], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax6 = sns.boxplot(y = model7_res['epochs'], ax = ax[6], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax7 = sns.boxplot(y = model8_res['epochs'], ax = ax[7], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax8 = sns.boxplot(y = model9_res['epochs'], ax = ax[8], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax9 = sns.boxplot(y = model10_res['epochs'], ax = ax[9], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax10 = sns.boxplot(y = model11_res['epochs'], ax = ax[10], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax11 = sns.boxplot(y = model12_res['epochs'], ax = ax[11], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})

ax0.set_title('L = 2 \n D = 64')
ax1.set_title('L = 2 \n D = 128')
ax2.set_title('L = 4 \n D = 64')
ax3.set_title('L = 4 \n D = 128')
ax4.set_title('L = 6 \n D = 64')
ax5.set_title('L = 6 \n D = 128')
ax6.set_title('L = 2 \n D = 64')
ax7.set_title('L = 2 \n D = 128')
ax8.set_title('L = 4 \n D = 64')
ax9.set_title('L = 4 \n D = 128')
ax10.set_title('L = 6 \n D = 64')
ax11.set_title('L = 6 \n D = 128')

ax0.set(ylabel = 'Epochs\nActivation = relu')
ax1.set(ylabel = '')
ax2.set(ylabel = '')
ax3.set(ylabel = '')
ax4.set(ylabel = '')
ax5.set(ylabel = '')
ax6.set(ylabel = 'Activation = leakyrelu')
ax7.set(ylabel = '')
ax8.set(ylabel = '')
ax9.set(ylabel = '')
ax10.set(ylabel = '')
ax11.set(ylabel = '')

fig.suptitle('Variance in Epochs Across Density\n Hidden Layers = L\nDensity = D')
fig.subplots_adjust(top = .85)

fig.savefig('epochs_density.png', dpi = 450, bbox_inches = 'tight');

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots(1, 12, figsize  = (12,8), sharey = True)

plt.subplots_adjust(hspace = 0.5, wspace = 0.1)

ax0 = sns.boxplot(y = model1_res['epochs'], ax = ax[0], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax1 = sns.boxplot(y = model2_res['epochs'], ax = ax[2], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax2 = sns.boxplot(y = model3_res['epochs'], ax = ax[4], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax3 = sns.boxplot(y = model4_res['epochs'], ax = ax[6], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax4 = sns.boxplot(y = model5_res['epochs'], ax = ax[8], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax5 = sns.boxplot(y = model6_res['epochs'], ax = ax[10], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax6 = sns.boxplot(y = model7_res['epochs'], ax = ax[1], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax7 = sns.boxplot(y = model8_res['epochs'], ax = ax[3], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax8 = sns.boxplot(y = model9_res['epochs'], ax = ax[5], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax9 = sns.boxplot(y = model10_res['epochs'], ax = ax[7], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax10 = sns.boxplot(y = model11_res['epochs'], ax = ax[9], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax11 = sns.boxplot(y = model12_res['epochs'], ax = ax[11], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})

ax0.set_title('L = 2 \n D = 64')
ax1.set_title('L = 2 \n D = 128')
ax2.set_title('L = 4 \n D = 64')
ax3.set_title('L = 4 \n D = 128')
ax4.set_title('L = 6 \n D = 64')
ax5.set_title('L = 6 \n D = 128')
ax6.set_title('L = 2 \n D = 64')
ax7.set_title('L = 2 \n D = 128')
ax8.set_title('L = 4 \n D = 64')
ax9.set_title('L = 4 \n D = 128')
ax10.set_title('L = 6 \n D = 64')
ax11.set_title('L = 6 \n D = 128')

ax0.set(ylabel = 'Epochs')
ax1.set(ylabel = '')
ax2.set(ylabel = '')
ax3.set(ylabel = '')
ax4.set(ylabel = '')
ax5.set(ylabel = '')
ax6.set(ylabel = '')
ax7.set(ylabel = '')
ax8.set(ylabel = '')
ax9.set(ylabel = '')
ax10.set(ylabel = '')
ax11.set(ylabel = '')

fig.suptitle('Variance in Epochs Across Layers\n Hidden Layers = L\nDensity = D')
fig.subplots_adjust(top = .85)

fig.savefig('epochs_layers.png', dpi = 450, bbox_inches = 'tight');

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots(1, 12, figsize  = (12,8), sharey = True)

plt.subplots_adjust(hspace = 0.5, wspace = 0.1)

ax0 = sns.boxplot(y = model1_res['epochs'], ax = ax[0], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax1 = sns.boxplot(y = model2_res['epochs'], ax = ax[2], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax2 = sns.boxplot(y = model3_res['epochs'], ax = ax[4], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax3 = sns.boxplot(y = model4_res['epochs'], ax = ax[6], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax4 = sns.boxplot(y = model5_res['epochs'], ax = ax[8], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax5 = sns.boxplot(y = model6_res['epochs'], ax = ax[10], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax6 = sns.boxplot(y = model7_res['epochs'], ax = ax[1], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax7 = sns.boxplot(y = model8_res['epochs'], ax = ax[3], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax8 = sns.boxplot(y = model9_res['epochs'], ax = ax[5], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax9 = sns.boxplot(y = model10_res['epochs'], ax = ax[7], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax10 = sns.boxplot(y = model11_res['epochs'], ax = ax[9], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax11 = sns.boxplot(y = model12_res['epochs'], ax = ax[11], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})

ax0.set_title('L = 2 \n D = 64')
ax1.set_title('L = 2 \n D = 128')
ax2.set_title('L = 4 \n D = 64')
ax3.set_title('L = 4 \n D = 128')
ax4.set_title('L = 6 \n D = 64')
ax5.set_title('L = 6 \n D = 128')
ax6.set_title('L = 2 \n D = 64')
ax7.set_title('L = 2 \n D = 128')
ax8.set_title('L = 4 \n D = 64')
ax9.set_title('L = 4 \n D = 128')
ax10.set_title('L = 6 \n D = 64')
ax11.set_title('L = 6 \n D = 128')

ax0.set(ylabel = 'Epochs')
ax1.set(ylabel = '')
ax2.set(ylabel = '')
ax3.set(ylabel = '')
ax4.set(ylabel = '')
ax5.set(ylabel = '')
ax6.set(ylabel = '')
ax7.set(ylabel = '')
ax8.set(ylabel = '')
ax9.set(ylabel = '')
ax10.set(ylabel = '')
ax11.set(ylabel = '')

fig.suptitle('Variance in Epochs Across Activation\n Hidden Layers = L\nDensity = D')
fig.subplots_adjust(top = .85)

fig.savefig('epochs_activation.png', dpi = 450, bbox_inches = 'tight');

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots(1, 12, figsize  = (12,8), sharey = True)

plt.subplots_adjust(hspace = 0.5, wspace = 0.1)

ax0 = sns.boxplot(y = model1_res['mae'], ax = ax[0], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax1 = sns.boxplot(y = model2_res['mae'], ax = ax[1], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax2 = sns.boxplot(y = model3_res['mae'], ax = ax[2], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax3 = sns.boxplot(y = model4_res['mae'], ax = ax[3], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax4 = sns.boxplot(y = model5_res['mae'], ax = ax[4], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax5 = sns.boxplot(y = model6_res['mae'], ax = ax[5], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax6 = sns.boxplot(y = model7_res['mae'], ax = ax[6], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax7 = sns.boxplot(y = model8_res['mae'], ax = ax[7], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax8 = sns.boxplot(y = model9_res['mae'], ax = ax[8], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax9 = sns.boxplot(y = model10_res['mae'], ax = ax[9], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax10 = sns.boxplot(y = model11_res['mae'], ax = ax[10], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax11 = sns.boxplot(y = model12_res['mae'], ax = ax[11], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})

ax0.set_title('L = 2\nD = 64')
ax1.set_title('L = 2\nD = 128')
ax2.set_title('L = 4 \n D = 64')
ax3.set_title('L = 4 \n D = 128')
ax4.set_title('L = 6 \n D = 64')
ax5.set_title('L = 6 \n D = 128')
ax6.set_title('L = 2 \n D = 64')
ax7.set_title('L = 2 \n D = 128')
ax8.set_title('L = 4 \n D = 64')
ax9.set_title('L = 4 \n D = 128')
ax10.set_title('L = 6 \n D = 64')
ax11.set_title('L = 6 \n D = 128')

ax0.set(ylabel = 'Mean Absolute Error\nActivation = relu')
ax1.set(ylabel = '')
ax2.set(ylabel = '')
ax3.set(ylabel = '')
ax4.set(ylabel = '')
ax5.set(ylabel = '')
ax6.set(ylabel = 'Activation = leakyrelu')
ax7.set(ylabel = '')
ax8.set(ylabel = '')
ax9.set(ylabel = '')
ax10.set(ylabel = '')
ax11.set(ylabel = '')

fig.suptitle('Variance in Mean Absolute Error Across Density\n Hidden Layers = L\nDensity = D')
fig.subplots_adjust(top = .85)

fig.savefig('mae_density.png', dpi = 450, bbox_inches = 'tight');

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots(1, 12, figsize  = (12,8), sharey = True)

plt.subplots_adjust(hspace = 0.5, wspace = 0.1)

ax0 = sns.boxplot(y = model1_res['mae'], ax = ax[0], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax1 = sns.boxplot(y = model2_res['mae'], ax = ax[2], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax2 = sns.boxplot(y = model3_res['mae'], ax = ax[4], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax3 = sns.boxplot(y = model4_res['mae'], ax = ax[6], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax4 = sns.boxplot(y = model5_res['mae'], ax = ax[8], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax5 = sns.boxplot(y = model6_res['mae'], ax = ax[10], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax6 = sns.boxplot(y = model7_res['mae'], ax = ax[1], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax7 = sns.boxplot(y = model8_res['mae'], ax = ax[3], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax8 = sns.boxplot(y = model9_res['mae'], ax = ax[5], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax9 = sns.boxplot(y = model10_res['mae'], ax = ax[7], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax10 = sns.boxplot(y = model11_res['mae'], ax = ax[9], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax11 = sns.boxplot(y = model12_res['mae'], ax = ax[11], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})

ax0.set_title('L = 2\nD = 64')
ax1.set_title('L = 2\nD = 128')
ax2.set_title('L = 4 \n D = 64')
ax3.set_title('L = 4 \n D = 128')
ax4.set_title('L = 6 \n D = 64')
ax5.set_title('L = 6 \n D = 128')
ax6.set_title('L = 2 \n D = 64')
ax7.set_title('L = 2 \n D = 128')
ax8.set_title('L = 4 \n D = 64')
ax9.set_title('L = 4 \n D = 128')
ax10.set_title('L = 6 \n D = 64')
ax11.set_title('L = 6 \n D = 128')

ax0.set(ylabel = 'Mean Absolute Error')
ax1.set(ylabel = '')
ax2.set(ylabel = '')
ax3.set(ylabel = '')
ax4.set(ylabel = '')
ax5.set(ylabel = '')
ax6.set(ylabel = '')
ax7.set(ylabel = '')
ax8.set(ylabel = '')
ax9.set(ylabel = '')
ax10.set(ylabel = '')
ax11.set(ylabel = '')

fig.suptitle('Variance in Mean Absolute Error Across Layers\n Hidden Layers = L\nDensity = D')
fig.subplots_adjust(top = .85)

fig.savefig('mae_layers.png', dpi = 450, bbox_inches = 'tight');

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots(1, 12, figsize  = (12,8), sharey = True)

plt.subplots_adjust(hspace = 0.5, wspace = 0.1)

ax0 = sns.boxplot(y = model1_res['mae'], ax = ax[0], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax1 = sns.boxplot(y = model2_res['mae'], ax = ax[2], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax2 = sns.boxplot(y = model3_res['mae'], ax = ax[4], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax3 = sns.boxplot(y = model4_res['mae'], ax = ax[6], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax4 = sns.boxplot(y = model5_res['mae'], ax = ax[8], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax5 = sns.boxplot(y = model6_res['mae'], ax = ax[10], showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax6 = sns.boxplot(y = model7_res['mae'], ax = ax[1], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax7 = sns.boxplot(y = model8_res['mae'], ax = ax[3], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax8 = sns.boxplot(y = model9_res['mae'], ax = ax[5], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax9 = sns.boxplot(y = model10_res['mae'], ax = ax[7], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax10 = sns.boxplot(y = model11_res['mae'], ax = ax[9], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})
ax11 = sns.boxplot(y = model12_res['mae'], ax = ax[11], palette = 'Greens', showmeans=True, meanprops={"marker":"o",
                                                                                  "markerfacecolor":"white", 
                                                                                  "markeredgecolor":"black",
                                                                                  "markersize":"6"})

ax0.set_title('L = 2\nD = 64')
ax1.set_title('L = 2\nD = 128')
ax2.set_title('L = 4 \n D = 64')
ax3.set_title('L = 4 \n D = 128')
ax4.set_title('L = 6 \n D = 64')
ax5.set_title('L = 6 \n D = 128')
ax6.set_title('L = 2 \n D = 64')
ax7.set_title('L = 2 \n D = 128')
ax8.set_title('L = 4 \n D = 64')
ax9.set_title('L = 4 \n D = 128')
ax10.set_title('L = 6 \n D = 64')
ax11.set_title('L = 6 \n D = 128')

ax0.set(ylabel = 'Mean Absolute Error')
ax1.set(ylabel = '')
ax2.set(ylabel = '')
ax3.set(ylabel = '')
ax4.set(ylabel = '')
ax5.set(ylabel = '')
ax6.set(ylabel = '')
ax7.set(ylabel = '')
ax8.set(ylabel = '')
ax9.set(ylabel = '')
ax10.set(ylabel = '')
ax11.set(ylabel = '')

fig.suptitle('Variance in Mean Absolute Error Across Activation\n Hidden Layers = L\nDensity = D')
fig.subplots_adjust(top = .85)

fig.savefig('mae_activation.png', dpi = 450, bbox_inches = 'tight');

# %%
model_mega_res
# Out:
#      model_num           loss_type            time  epochs        r2  \
# 0          1.0  mean_squared_error  0:11:35.052522     250  0.181457
# 1          2.0  mean_squared_error  0:01:36.080798      33  0.193403
# 2          3.0  mean_squared_error  0:02:28.204412      51  0.190455
# 3          4.0  mean_squared_error  0:01:24.386754      29  0.183975
# 4          5.0  mean_squared_error  0:01:36.555882      33  0.180941
# ..         ...                 ...             ...     ...       ...
# 245      246.0  mean_squared_error  0:01:56.305673      38  0.193645
# 246      247.0  mean_squared_error  0:02:28.542397      48  0.192692
# 247      248.0  mean_squared_error  0:02:40.109522      52  0.191570
# 248      249.0  mean_squared_error  0:01:46.903562      35  0.193694
# 249      250.0  mean_squared_error  0:01:37.206876      32  0.190322
#
#           mae       mse      rmse  max_error  layers  density activation  \
# ...

# %%
res_grouped_mean = model_mega_res.groupby(['layers','density','activation']).mean()
res_grouped_median = model_mega_res.groupby(['layers','density','activation']).median()
res_grouped_layers = model_mega_res.groupby(['layers']).mean()
res_grouped_density = model_mega_res.groupby(['density']).mean()
res_grouped_activation = model_mega_res.groupby(['activation']).mean()

# %%
res_grouped_mean
# Out:
#                            model_num  epochs        r2       mae       mse  \
# layers density activation
# 2      64      leakyrelu       125.5  46.832  0.191530  0.229236  0.216095
#                relu            125.5  46.432  0.191712  0.229200  0.216047
#        128     leakyrelu       125.5  48.678  0.191258  0.229318  0.216168
#                relu            125.5  48.046  0.191659  0.229156  0.216061
# 4      64      leakyrelu       125.5  48.382  0.191119  0.229473  0.216205
#                relu            250.5  45.176  0.190653  0.229727  0.216329
#        128     leakyrelu       125.5  47.172  0.191415  0.229310  0.216126
#                relu            250.5  46.928  0.190487  0.229717  0.216374
# 6      64      leakyrelu       125.5  47.080  0.190836  0.229709  0.216281
#                relu            125.5  44.710  0.190207  0.230553  0.216449
#        128     leakyrelu       125.5  46.562  0.191033  0.229591  0.216228
# ...

# %%
res_grouped_layers
# Out:
#         model_num   epochs        r2       mae       mse      rmse  max_error  \
# layers
# 2           125.5  47.4970  0.191540  0.229228  0.216092  0.464857   5.232210
# 4           188.0  46.9145  0.190919  0.229557  0.216259  0.465035   5.240895
# 6           125.5  46.5075  0.190768  0.229881  0.216299  0.465078   5.237887
#
#         density
# layers
# 2          96.0
# 4          96.0
# 6          96.0

# %%
sns.set_style('whitegrid')
sns.set_palette('bright')

fig, (ax0) = plt.subplots(1, figsize = (30,10))

ax0 = sns.barplot(x = 'mae', y = 'layers', data = res_grouped_layers.reset_index(), orient = 'h')

ax0.set_title('Mean MAE Across Layers')
ax0.set(xlabel = 'MAE', ylabel = 'Layers')

#fig.savefig('mae_vs_layers.png', dpi = 450, bbox_inches = 'tight');
# Out:
# [Text(0.5, 0, 'MAE'), Text(0, 0.5, 'Layers')]

# %%
sns.set_style('whitegrid')
sns.set_palette('bright')

fig, (ax0) = plt.subplots(1, figsize = (30,10))

ax0 = sns.barplot(x = 'mae', y = 'density', data = res_grouped_density.reset_index(), orient = 'h')

ax0.set_title('Mean MAE Across Density')
ax0.set(xlabel = 'MAE', ylabel = 'Density')

#fig.savefig('mae_vs_density.png', dpi = 450, bbox_inches = 'tight');
# Out:
# [Text(0.5, 0, 'MAE'), Text(0, 0.5, 'Density')]

# %%
sns.set_style('whitegrid')
sns.set_palette('bright')

fig, (ax0) = plt.subplots(1, figsize = (30,10))

ax0 = sns.barplot(x = 'mae', y = 'activation', data = res_grouped_activation.reset_index(), orient = 'h')

ax0.set_title('Mean MAE Across Activation')
ax0.set(xlabel = 'MAE', ylabel = 'activation')

#fig.savefig('mae_vs_activation.png', dpi = 450, bbox_inches = 'tight');
# Out:
# [Text(0.5, 0, 'MAE'), Text(0, 0.5, 'activation')]
