# %%
import numpy as np
import pandas as pd

import datetime as dt

# %%
#Code to use only once which loads in CSVs and joins them based on the model parameter type

#model5_pred_1 = pd.read_csv('data/rnn_predictions_5_1.csv', index_col = 0)
#model5_pred_2 = pd.read_csv('data/rnn_predictions_5_2.csv', index_col = 0)

#model5_res_1 = pd.read_csv('data/rnn_results_5_1.csv', index_col = 0)
#model5_res_2 = pd.read_csv('data/rnn_results_5_2.csv', index_col = 0)

#model6_pred_1 = pd.read_csv('data/rnn_predictions_6_1.csv', index_col = 0)
#model6_pred_2 = pd.read_csv('data/rnn_predictions_6_2.csv', index_col = 0)

#model6_res_1 = pd.read_csv('data/rnn_results_6_1.csv', index_col = 0)
#model6_res_2 = pd.read_csv('data/rnn_results_6_2.csv', index_col = 0)

#model7_pred_1 = pd.read_csv('data/rnn_predictions_7_1.csv', index_col = 0)
#model7_pred_2 = pd.read_csv('data/rnn_predictions_7_2.csv', index_col = 0)

#model7_res_1 = pd.read_csv('data/rnn_results_7_1.csv', index_col = 0)
#model7_res_2 = pd.read_csv('data/rnn_results_7_2.csv', index_col = 0)

#model8_pred_1 = pd.read_csv('data/rnn_predictions_8_1.csv', index_col = 0)
#model8_pred_2 = pd.read_csv('data/rnn_predictions_8_2.csv', index_col = 0)

#model8_res_1 = pd.read_csv('data/rnn_results_8_1.csv', index_col = 0)
#model8_res_2 = pd.read_csv('data/rnn_results_8_2.csv', index_col = 0)

#model9_pred_1 = pd.read_csv('data/rnn_predictions_9_1.csv', index_col = 0)
#model9_pred_2 = pd.read_csv('data/rnn_predictions_9_2.csv', index_col = 0)

#model9_res_1 = pd.read_csv('data/rnn_results_9_1.csv', index_col = 0)
#model9_res_2 = pd.read_csv('data/rnn_results_9_2.csv', index_col = 0)

#model10_pred_1 = pd.read_csv('data/rnn_predictions_10_1.csv', index_col = 0)
#model10_pred_2 = pd.read_csv('data/rnn_predictions_10_2.csv', index_col = 0)

#model10_res_1 = pd.read_csv('data/rnn_results_10_1.csv', index_col = 0)
#model10_res_2 = pd.read_csv('data/rnn_results_10_2.csv', index_col = 0)

#model11_pred_1 = pd.read_csv('data/rnn_predictions_11_1.csv', index_col = 0)
#model11_pred_2 = pd.read_csv('data/rnn_predictions_11_2.csv', index_col = 0)

#model11_res_1 = pd.read_csv('data/rnn_results_11_1.csv', index_col = 0)
#model11_res_2 = pd.read_csv('data/rnn_results_11_2.csv', index_col = 0)

#model12_pred_1 = pd.read_csv('data/rnn_predictions_12_1.csv', index_col = 0)
#model12_pred_2 = pd.read_csv('data/rnn_predictions_12_2.csv', index_col = 0)

#model12_res_1 = pd.read_csv('data/rnn_results_12_1.csv', index_col = 0)
#model12_res_2 = pd.read_csv('data/rnn_results_12_2.csv', index_col = 0)

# %%
#Code to use only once which then concacts the like models together into their own dataframes

#model5_pred = pd.concat([model5_pred_1, model5_pred_2], axis = 0)
#model6_pred = pd.concat([model6_pred_1, model6_pred_2], axis = 0)
#model7_pred = pd.concat([model7_pred_1, model7_pred_2], axis = 0)
#model8_pred = pd.concat([model8_pred_1, model8_pred_2], axis = 0)
#model9_pred = pd.concat([model9_pred_1, model9_pred_2], axis = 0)
#model10_pred = pd.concat([model10_pred_1, model10_pred_2], axis = 0)
#model11_pred = pd.concat([model11_pred_1, model11_pred_2], axis = 0)
#model12_pred = pd.concat([model12_pred_1, model12_pred_2], axis = 0)

#model5_res = pd.concat([model5_res_1, model5_res_2], axis = 0)
#model6_res = pd.concat([model6_res_1, model6_res_2], axis = 0)
#model7_res = pd.concat([model7_res_1, model7_res_2], axis = 0)
#model8_res = pd.concat([model8_res_1, model8_res_2], axis = 0)
#model9_res = pd.concat([model9_res_1, model9_res_2], axis = 0)
#model10_res = pd.concat([model10_res_1, model10_res_2], axis = 0)
#model11_res = pd.concat([model11_res_1, model11_res_2], axis = 0)
#model12_res = pd.concat([model12_res_1, model12_res_2], axis = 0)

# %%
model1_pred = pd.read_csv('data/rnn_predictions_1.csv', index_col = 0)
model1_res = pd.read_csv('data/rnn_results_1.csv', index_col = 0)

model2_pred = pd.read_csv('data/rnn_predictions_2.csv', index_col = 0)
model2_res = pd.read_csv('data/rnn_results_2.csv', index_col = 0)

model3_pred = pd.read_csv('data/rnn_predictions_3.csv', index_col = 0)
model3_res = pd.read_csv('data/rnn_results_3.csv', index_col = 0)

model4_pred = pd.read_csv('data/rnn_predictions_4.csv', index_col = 0)
model4_res = pd.read_csv('data/rnn_results_4.csv', index_col = 0)

model5_pred = pd.read_csv('data/rnn_predictions_5.csv', index_col = 0)
model5_res = pd.read_csv('data/rnn_results_5.csv', index_col = 0)

model6_pred = pd.read_csv('data/rnn_predictions_6.csv', index_col = 0)
model6_res = pd.read_csv('data/rnn_results_6.csv', index_col = 0)

model7_pred = pd.read_csv('data/rnn_predictions_7.csv', index_col = 0)
model7_res = pd.read_csv('data/rnn_results_7.csv', index_col = 0)

model8_pred = pd.read_csv('data/rnn_predictions_8.csv', index_col = 0)
model8_res = pd.read_csv('data/rnn_results_8.csv', index_col = 0)

model9_pred = pd.read_csv('data/rnn_predictions_9.csv', index_col = 0)
model9_res = pd.read_csv('data/rnn_results_9.csv', index_col = 0)

model10_pred = pd.read_csv('data/rnn_predictions_10.csv', index_col = 0)
model10_res = pd.read_csv('data/rnn_results_10.csv', index_col = 0)

model11_pred = pd.read_csv('data/rnn_predictions_11.csv', index_col = 0)
model11_res = pd.read_csv('data/rnn_results_11.csv', index_col = 0)

model12_pred = pd.read_csv('data/rnn_predictions_12.csv', index_col = 0)
model12_res = pd.read_csv('data/rnn_results_12.csv', index_col = 0)

# %%
#Adds columns to each dataframe with the varying parameters for that model so they can be compared in one dataframe later

#model1_res['layers'] = 2
#model2_res['layers'] = 2
#model3_res['layers'] = 4
#model4_res['layers'] = 4
#model5_res['layers'] = 6
#model6_res['layers'] = 6
#model7_res['layers'] = 2
#model8_res['layers'] = 2
#model9_res['layers'] = 4
#model10_res['layers'] = 4
#model11_res['layers'] = 6
#model12_res['layers'] = 6

#model1_res['density'] = 64
#model2_res['density'] = 128
#model3_res['density'] = 64
#model4_res['density'] = 128
#model5_res['density'] = 64
#model6_res['density'] = 128
#model7_res['density'] = 64
#model8_res['density'] = 128
#model9_res['density'] = 64
#model10_res['density'] = 128
#model11_res['density'] = 64
#model12_res['density'] = 128

#model1_res['activation'] = 'relu'
#model2_res['activation'] = 'relu'
#model3_res['activation'] = 'relu'
#model4_res['activation'] = 'relu'
#model5_res['activation'] = 'relu'
#model6_res['activation'] = 'relu'
#model7_res['activation'] = 'leakyrelu'
#model8_res['activation'] = 'leakyrelu'
#model9_res['activation'] = 'leakyrelu'
#model10_res['activation'] = 'leakyrelu'
#model11_res['activation'] = 'leakyrelu'
#model12_res['activation'] = 'leakyrelu'

# %%
#Creates a timedelta column by which we can perform calculations with 

model1_res['time_delta'] = pd.to_timedelta(model1_res['time'])
model2_res['time_delta'] = pd.to_timedelta(model2_res['time'])
model3_res['time_delta'] = pd.to_timedelta(model3_res['time'])
model4_res['time_delta'] = pd.to_timedelta(model4_res['time'])
model5_res['time_delta'] = pd.to_timedelta(model5_res['time'])
model6_res['time_delta'] = pd.to_timedelta(model6_res['time'])
model7_res['time_delta'] = pd.to_timedelta(model7_res['time'])
model8_res['time_delta'] = pd.to_timedelta(model8_res['time'])
model9_res['time_delta'] = pd.to_timedelta(model9_res['time'])
model10_res['time_delta'] = pd.to_timedelta(model10_res['time'])
model11_res['time_delta'] = pd.to_timedelta(model11_res['time'])
model12_res['time_delta'] = pd.to_timedelta(model12_res['time'])

# %%
#Outputs the csvs to the data folder

model1_pred.to_csv('data/rnn_predictions_1.csv')
model2_pred.to_csv('data/rnn_predictions_2.csv')
model3_pred.to_csv('data/rnn_predictions_3.csv')
model4_pred.to_csv('data/rnn_predictions_4.csv')
model5_pred.to_csv('data/rnn_predictions_5.csv')
model6_pred.to_csv('data/rnn_predictions_6.csv')
model7_pred.to_csv('data/rnn_predictions_7.csv')
model8_pred.to_csv('data/rnn_predictions_8.csv')
model9_pred.to_csv('data/rnn_predictions_9.csv')
model10_pred.to_csv('data/rnn_predictions_10.csv')
model11_pred.to_csv('data/rnn_predictions_11.csv')
model12_pred.to_csv('data/rnn_predictions_12.csv')

model1_res.to_csv('data/rnn_results_1.csv')
model2_res.to_csv('data/rnn_results_2.csv')
model3_res.to_csv('data/rnn_results_3.csv')
model4_res.to_csv('data/rnn_results_4.csv')
model5_res.to_csv('data/rnn_results_5.csv')
model6_res.to_csv('data/rnn_results_6.csv')
model7_res.to_csv('data/rnn_results_7.csv')
model8_res.to_csv('data/rnn_results_8.csv')
model9_res.to_csv('data/rnn_results_9.csv')
model10_res.to_csv('data/rnn_results_10.csv')
model11_res.to_csv('data/rnn_results_11.csv')
model12_res.to_csv('data/rnn_results_12.csv')

# %%
#Creates a list of all model result dataframe titles 
frames = [model1_res, model2_res, model3_res, model4_res, model5_res, model6_res, 
          model7_res, model8_res, model9_res, model10_res, model11_res, model12_res]

# %%
#Concats all result dataframes into one dataframe
model_mega_res = pd.concat(frames, axis = 0)

# %%
model_mega_res.to_csv('data/rnn_results_1to12.csv')
